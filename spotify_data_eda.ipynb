# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt             

# %matplotlib inline     
sns.set(color_codes=True)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("spotify_global_2019_most_streamed_tracks_audio_features.csv")
df.head()
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309      Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359          Señorita
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 3    Tones and I  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 4   Shawn Mendes  https://open.spotify.com/track/6v3KW9xbzN5yKLt...
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0691         0.719   0.704          0.000000    0.1660    -4.724
# 1        0.3280         0.701   0.425          0.130000    0.1000   -10.965
# 2        0.5920         0.778   0.317          0.000000    0.0881   -10.732
# 3        0.6880         0.825   0.593          0.000161    0.1700    -6.401
# 4        0.0392         0.759   0.548          0.000000    0.0828    -6.049
#
#    speechiness  valence    tempo  time_signature  duration_ms  key  mode  \
# 0       0.0476    0.628  133.002               4       187436    1     1
# 1       0.3750    0.562  135.128               4       194088    7     1
# 2       0.3340    0.327  140.048               4       178627    1     0
# 3       0.0988    0.540   98.078               4       209755    6     0
# 4       0.0290    0.749  116.967               4       190800    9     0
#
#                 Artist_id  Artist_popularity  Artist_follower  \
# 0  4npEfmQ6YuiwW1GpUmaq3F                 87          1025358
# 1  6qqNVTkY8uBg9cP3Jd7DAH                 98         18867904
# 2  66CXWjxzNUsdJxJ2JdwvnR                 97         40958727
# 3  2NjfBq1NflQcKSeiDooVjY                 92           484241
# 4  7n2wHs1TKAczGzO7Dd2rGr                 94         23152263
#
#                                           Artist_img
# 0  https://i.scdn.co/image/4b914c6470c8458674538a...
# 1  https://i.scdn.co/image/2622edec99d68d1d141886...
# 2  https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 3  https://i.scdn.co/image/c128f5ef4d210a67610acd...
# 4  https://i.scdn.co/image/6bd59cfbd3e1e6394af710...

# %%
df.shape
# Out:
# (1717, 24)

# %%
df.dtypes
# Out:
# Country               object
# Rank                 float64
# Track_id              object
# Streams                int64
# Track Name            object
# Artist                object
# URL                   object
# acousticness         float64
# danceability         float64
# energy               float64
# instrumentalness     float64
# liveness             float64
# loudness             float64
# speechiness          float64
# valence              float64
# tempo                float64
# time_signature         int64
# duration_ms            int64
# key                    int64
# mode                   int64
# Artist_id             object
# Artist_popularity      int64
# Artist_follower        int64
# Artist_img            object
# dtype: object

# %% [markdown]
# ### 기술통계

# %%
df.describecribe()
# Out:
#               Rank       Streams  acousticness  danceability       energy  \
# count  1717.000000  1.717000e+03   1717.000000   1717.000000  1717.000000
# mean    859.000000  5.166175e+07      0.257652      0.675438     0.624354
# std     495.799523  1.047532e+08      0.256975      0.154163     0.172298
# min       1.000000  5.242300e+05      0.000037      0.151000     0.013700
# 25%     430.000000  1.763026e+06      0.051900      0.584000     0.525000
# 50%     859.000000  9.623926e+06      0.171000      0.694000     0.646000
# 75%    1288.000000  4.829352e+07      0.385000      0.787000     0.747000
# max    1717.000000  1.166186e+09      0.979000      0.974000     0.978000
#
#        instrumentalness     liveness     loudness  speechiness      valence  \
# count       1717.000000  1717.000000  1717.000000  1717.000000  1717.000000
# mean           0.014577     0.174317    -6.477624     0.129967     0.487719
# std            0.085988     0.135992     2.777252     0.113958     0.220402
# min            0.000000     0.019700   -25.166000     0.023200     0.026200
# 25%            0.000000     0.097200    -7.595000     0.044600     0.321000
# 50%            0.000000     0.123000    -5.991000     0.080100     0.490000
# 75%            0.000022     0.198000    -4.696000     0.188000     0.652000
# max            0.956000     0.959000    -1.339000     0.856000     0.982000
#
#              tempo  time_signature    duration_ms          key         mode  \
# count  1717.000000     1717.000000    1717.000000  1717.000000  1717.000000
# mean    122.147556        3.942341  202604.382644     5.332557     0.582994
# std      30.734280        0.373427   58229.593358     3.677810     0.493208
# min      46.489000        1.000000   46837.000000     0.000000     0.000000
# 25%      97.038000        4.000000  171573.000000     2.000000     0.000000
# 50%     120.013000        4.000000  196400.000000     6.000000     1.000000
# 75%     143.027000        4.000000  224225.000000     8.000000     1.000000
# max     207.476000        5.000000  943529.000000    11.000000     1.000000
#
#        Artist_popularity  Artist_follower
# count        1717.000000     1.717000e+03
# mean           87.246942     8.645130e+06
# std             7.808209     1.105793e+07
# min            47.000000     1.090000e+02
# 25%            83.000000     1.370858e+06
# 50%            87.000000     3.998147e+06
# 75%            93.000000     1.099547e+07
# max           100.000000     5.746376e+07

# %%
# 불필요한 컬럼 제거(임의 선택, 초안)
new_df = df.drop(['Country', 'Track_id', 'URL', 'Artist_id', 'Artist_img'], axis=1)
new_df.head(10)
# Out:
#    Rank     Streams         Track Name         Artist  acousticness  \
# 0   1.0  1166185736   Sweet but Psycho        Ava Max        0.0691
# 1   2.0  1052358787            bad guy  Billie Eilish        0.3280
# 2   3.0   789094044            7 rings  Ariana Grande        0.5920
# 3   4.0   764208309       Dance Monkey    Tones and I        0.6880
# 4   5.0   763064359           Señorita   Shawn Mendes        0.0392
# 5   6.0   715027898          Con Calma   Daddy Yankee        0.1100
# 6   7.0   714097238            Shallow      Lady Gaga        0.3710
# 7   8.0   661930419  Someone You Loved  Lewis Capaldi        0.7510
# 8   9.0   620829467            Happier     Marshmello        0.1910
# 9  10.0   615519053               Wow.    Post Malone        0.1630
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.719   0.704          0.000000    0.1660    -4.724       0.0476
# 1         0.701   0.425          0.130000    0.1000   -10.965       0.3750
# 2         0.778   0.317          0.000000    0.0881   -10.732       0.3340
# 3         0.825   0.593          0.000161    0.1700    -6.401       0.0988
# 4         0.759   0.548          0.000000    0.0828    -6.049       0.0290
# 5         0.737   0.860          0.000002    0.0574    -2.652       0.0593
# 6         0.572   0.385          0.000000    0.2310    -6.362       0.0308
# 7         0.501   0.405          0.000000    0.1050    -5.679       0.0319
# 8         0.687   0.792          0.000000    0.1670    -2.749       0.0452
# 9         0.833   0.539          0.000002    0.1010    -7.399       0.1780
#
#    valence    tempo  time_signature  duration_ms  key  mode  \
# 0    0.628  133.002               4       187436    1     1
# 1    0.562  135.128               4       194088    7     1
# 2    0.327  140.048               4       178627    1     0
# 3    0.540   98.078               4       209755    6     0
# 4    0.749  116.967               4       190800    9     0
# 5    0.656   93.989               4       193227    8     0
# 6    0.323   95.799               4       215733    7     1
# 7    0.446  109.891               4       182161    1     1
# 8    0.671  100.015               4       214290    5     1
# 9    0.385   99.947               4       149520   11     0
#
#    Artist_popularity  Artist_follower
# 0                 87          1025358
# 1                 98         18867904
# 2                 97         40958727
# 3                 92           484241
# 4                 94         23152263
# 5                 95         15857952
# 6                 89         10181517
# 7                 92          2143489
# 8                 90         20341696
# 9                100         21335421

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(new_df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
print("Mean value for danceability:", new_df['danceability'].mean())
sns.distplot(new_df['danceability'])
plt.show()
print("Mean value for energy:", new_df['energy'].mean())
sns.distplot(new_df['energy'])
plt.show()
print("Mean value for mode:", new_df['mode'].mean())
sns.distplot(new_df['mode'])
plt.show()
print("Mean value for speechiness:", new_df['speechiness'].mean())
sns.distplot(new_df['speechiness'])
plt.show()
print("Mean value for acousticness:", new_df['acousticness'].mean())
sns.distplot(new_df['acousticness'])
plt.show()
print("Mean value for instrumentalness:", new_df['instrumentalness'].mean())
sns.distplot(new_df['instrumentalness'])
plt.show()
print("Mean value for liveness:", new_df['liveness'].mean())
sns.distplot(new_df['liveness'])
plt.show()
print("Mean value for valence:", new_df['valence'].mean())
sns.distplot(new_df['valence'])
plt.show()
# Out:
# Mean value for danceability: 0.6754379732090855
# Mean value for energy: 0.6243543972044264
# Mean value for mode: 0.5829935934769948
# Mean value for speechiness: 0.12996686080372744
# Mean value for acousticness: 0.2576517161910309
# Mean value for instrumentalness: 0.014577336150262084
# Mean value for liveness: 0.17431665695981363
# Mean value for valence: 0.4877186371578335

# %%
numeric = new_df.drop(['Rank','Streams','Artist_popularity', 'Artist_follower'], axis=1)
small = numeric.drop(['tempo','duration_ms','key', 'loudness', 'time_signature'], axis=1)
sns.set_palette('pastel')
small.mean().plot.bar()
plt.title('Mean Values of Audio Features')
plt.show()
